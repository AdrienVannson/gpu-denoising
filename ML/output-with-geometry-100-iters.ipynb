# %% [markdown]
# # Denoising Autoencoder

# %% [markdown]
# To start the backend:
# ```
# sudo docker run -it --rm --runtime=nvidia -v $(realpath ~/Documents/ML):/tf/notebooks -p 8888:8888 tensorflow/tensorflow:latest-gpu-jupyter
# ```

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.python.client import device_lib
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
import os

# Needed when using the docker backend
if 'notebooks' in os.listdir():
    os.chdir('notebooks')

# Check if the GPU is detected
local_device_protos = device_lib.list_local_devices()
[x.name for x in local_device_protos]
# Out:
# 2023-07-24 17:30:03.636720: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-24 17:30:03.754380: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-24 17:30:05.444712: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 17:30:05.460930: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 17:30:05.461124: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 17:30:05.515307: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 17:30:05.515411: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 17:30:05.515464: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 17:30:05.515526: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:0 with 5820 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# ['/device:CPU:0', '/device:GPU:0']

# %%
TILE_SIZE = 128
TILES_PER_IMAGE = 30

EPOCHS_COUNT = 100

WITH_GEOMETRY = True

GEOMETRY_CHANNELS_COUNT = 4 if WITH_GEOMETRY else 0
INPUT_CHANNELS_COUNT = 3 + GEOMETRY_CHANNELS_COUNT

MODEL_NAME = str(EPOCHS_COUNT) + '-with' + ('' if WITH_GEOMETRY else 'out') + '-geometry'

# %%
def read_image_file(filename, geometry_file = None):
    WIDTH, HEIGHT = 1024, 1024

    # return tf.constant(np.random.rand(HEIGHT, WIDTH, 3 + (GEOMETRY_CHANNELS_COUNT if geometry_file is not None else 0)), dtype=tf.float16)

    image_data = []
    with open(filename, 'r') as file:
        for line in file:
            values = line.strip().split()
            image_data.append([float(value) for value in values])

    if WITH_GEOMETRY and geometry_file is not None:
        with open(geometry_file, 'r') as file:
            for i, line in enumerate(file):
                values = [float(v) for v in line.strip().split()]
                assert(values[0] <= 100)
                values[0] /= 20 # TODO specific for this scene.. TODO divide by the max
                image_data[i] += values

    image_tensor = tf.constant(image_data, dtype=np.float16)
    image_tensor = tf.reshape(image_tensor, [HEIGHT, WIDTH, 3 + (GEOMETRY_CHANNELS_COUNT if geometry_file is not None else 0)])

    # TODO the file is not stored line by line
    image_tensor = tf.image.rot90(image_tensor)

    return image_tensor


def display_img(img):
    plt.imshow(img.numpy().astype(np.float32)[:,:,:3])
    plt.axis('off')
    plt.show()

# %%
def generate_tiles(img, n, seed=0):
    # return [tf.convert_to_tensor(np.random.rand(TILE_SIZE, TILE_SIZE, len(img[0][0])), dtype=tf.float16) for _ in range(n)]
    return [
        tf.image.stateless_random_flip_left_right(
            tf.image.stateless_random_crop(img, size=(TILE_SIZE, TILE_SIZE, len(img[0][0])), seed=(seed, i)),
            seed=(seed, i)
        )
        for i in range(n)
    ]

def display_tile_grid(tiles, lines_count=4, columns_count=2, size=2):
    fig, axes = plt.subplots(lines_count, columns_count*len(tiles), figsize=(size*columns_count*len(tiles), size*lines_count))

    for i in range(lines_count):
        for j in range(columns_count):
            for k in range(len(tiles)):
                ax = axes[i, j*len(tiles) + k]
                ax.imshow(tiles[k][i*columns_count + j].numpy().astype(np.float32)[:,:,:3])
                ax.axis('off')

    fig.tight_layout()
    plt.show()

# %%
images = []
for i in range(30):
    for c in ['a', 'b', 'c']:
        folder = 'data/output-' + str(i).zfill(4)
        img_input = read_image_file(folder + '/raw-output-00004-' + c, geometry_file = folder + '/geometry')
        img_output = read_image_file(folder + '/raw-output-10000')

        images.append((img_input, img_output))
# Out:
# 2023-07-24 17:30:07.726103: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 17:30:07.726223: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 17:30:07.726262: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 17:30:07.726447: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 17:30:07.726494: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 17:30:07.726530: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 17:30:07.726593: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 17:30:07.726631: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 17:30:07.726666: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5820 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
display_img(images[0][0])
display_img(images[0][1])

if WITH_GEOMETRY:
    plt.imshow(images[0][0][:,:,3])
    plt.axis('off')
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
tiles_input = []
tiles_expected = []

for i in range(30):
    for j in range(3):
        img_input, img_expected = images[i*3 + j]

        tiles_input += generate_tiles(img_input, TILES_PER_IMAGE, seed=i)
        tiles_expected += generate_tiles(img_expected, TILES_PER_IMAGE, seed=i)

tiles_input, tiles_expected = tf.convert_to_tensor(tiles_input), tf.convert_to_tensor(tiles_expected)

display_tile_grid([tiles_input, tiles_expected])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Validation
validation_images = []
for i in range(34, 36):
    for c in ['a']:
        folder = 'data/output-' + str(i).zfill(4)
        img_input = read_image_file(folder + '/raw-output-00004-' + c, geometry_file = folder + '/geometry')
        img_output = read_image_file(folder + '/raw-output-10000')

        validation_images.append((img_input, img_output))

validation_tiles_input = []
validation_tiles_expected = []

for img_input, img_expected in validation_images:
    validation_tiles_input += generate_tiles(img_input, TILES_PER_IMAGE)
    validation_tiles_expected += generate_tiles(img_expected, TILES_PER_IMAGE)

validation_tiles_input, validation_tiles_expected = tf.convert_to_tensor(validation_tiles_input), tf.convert_to_tensor(validation_tiles_expected)

# %% [markdown]
# ## CNN

# %%
input_shape = (None, None, INPUT_CHANNELS_COUNT)

inputs = tf.keras.Input(shape=input_shape)

x_128 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)

x_64 = layers.MaxPooling2D((2, 2))(x_128)
x_64 = layers.Conv2D(43, (3, 3), activation='relu', padding='same')(x_64)

x_32 = layers.MaxPooling2D((2, 2))(x_64)
x_32 = layers.Conv2D(57, (3, 3), activation='relu', padding='same')(x_32)

x_16 = layers.MaxPooling2D((2, 2))(x_32)
x_16 = layers.Conv2D(76, (3, 3), activation='relu', padding='same')(x_16)

x_8 = layers.MaxPooling2D((2, 2))(x_16)
x_8 = layers.Conv2D(101, (3, 3), activation='relu', padding='same')(x_8)

x_4 = layers.MaxPooling2D((2, 2))(x_8)
x_4 = layers.Conv2D(101, (3, 3), activation='relu', padding='same')(x_4)

x = layers.UpSampling2D(size=(2, 2))(x_4)
x = layers.Concatenate()([x, x_8]) # Skip connection
x = layers.Conv2D(101, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(101, (3, 3), activation='relu', padding='same')(x)

x = layers.UpSampling2D(size=(2, 2))(x)
x = layers.Concatenate()([x, x_16]) # Skip connection
x = layers.Conv2D(76, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(76, (3, 3), activation='relu', padding='same')(x)

x = layers.UpSampling2D(size=(2, 2))(x)
x = layers.Concatenate()([x, x_32]) # Skip connection
x = layers.Conv2D(57, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(57, (3, 3), activation='relu', padding='same')(x)

x = layers.UpSampling2D(size=(2, 2))(x)
x = layers.Concatenate()([x, x_64]) # Skip connection
x = layers.Conv2D(43, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(43, (3, 3), activation='relu', padding='same')(x)

x = layers.UpSampling2D(size=(2, 2))(x)
x = layers.Concatenate()([x, x_128]) # Skip connection
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(3, (3, 3), activation='relu', padding='same')(x)

outputs = x

# Create the model
model = tf.keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='mean_absolute_error')

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, None, 7)]      0         []
#
#  conv2d (Conv2D)             (None, None, None, 32)       2048      ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, None, None, 32)       0         ['conv2d[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, None, None, 43)       12427     ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, None, None, 43)       0         ['conv2d_1[0][0]']
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, None, None, 57)       22116     ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, None, None, 57)       0         ['conv2d_2[0][0]']
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, None, None, 76)       39064     ['max_pooling2d_2[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, None, None, 76)       0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, None, None, 101)      69185     ['max_pooling2d_3[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, None, None, 101)      0         ['conv2d_4[0][0]']
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, None, None, 101)      91910     ['max_pooling2d_4[0][0]']
#
#  up_sampling2d (UpSampling2  (None, None, None, 101)      0         ['conv2d_5[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, None, None, 202)      0         ['up_sampling2d[0][0]',
#                                                                      'conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)           (None, None, None, 101)      183719    ['concatenate[0][0]']
#
#  conv2d_7 (Conv2D)           (None, None, None, 101)      91910     ['conv2d_6[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, None, None, 101)      0         ['conv2d_7[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, None, None, 177)      0         ['up_sampling2d_1[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_8 (Conv2D)           (None, None, None, 76)       121144    ['concatenate_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, None, None, 76)       52060     ['conv2d_8[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, None, None, 76)       0         ['conv2d_9[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, None, None, 133)      0         ['up_sampling2d_2[0][0]',
#  )                                                                   'conv2d_2[0][0]']
#
#  conv2d_10 (Conv2D)          (None, None, None, 57)       68286     ['concatenate_2[0][0]']
#
#  conv2d_11 (Conv2D)          (None, None, None, 57)       29298     ['conv2d_10[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, None, None, 57)       0         ['conv2d_11[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, None, None, 100)      0         ['up_sampling2d_3[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_12 (Conv2D)          (None, None, None, 43)       38743     ['concatenate_3[0][0]']
#
#  conv2d_13 (Conv2D)          (None, None, None, 43)       16684     ['conv2d_12[0][0]']
#
#  up_sampling2d_4 (UpSamplin  (None, None, None, 43)       0         ['conv2d_13[0][0]']
#  g2D)
#
#  concatenate_4 (Concatenate  (None, None, None, 75)       0         ['up_sampling2d_4[0][0]',
#  )                                                                   'conv2d[0][0]']
#
#  conv2d_14 (Conv2D)          (None, None, None, 32)       21632     ['concatenate_4[0][0]']
#
#  conv2d_15 (Conv2D)          (None, None, None, 3)        867       ['conv2d_14[0][0]']
#
# ==================================================================================================
# Total params: 861093 (3.28 MB)
# Trainable params: 861093 (3.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Train the model if needed
if os.path.isfile('models/' + MODEL_NAME + '.index'):
    model.load_weights('models/' + MODEL_NAME)
else:
    hist = model.fit(tiles_input, tiles_expected, epochs=EPOCHS_COUNT, validation_data=(validation_tiles_input, validation_tiles_expected))

    training_loss = hist.history['loss']
    validation_loss = hist.history['val_loss']

    model.save_weights('models/' + MODEL_NAME)
# Out:
# Epoch 1/100
# 2023-07-24 17:35:23.107779: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-07-24 17:35:24.031905: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f06c34656f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-07-24 17:35:24.031942: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3070 Ti, Compute Capability 8.6
# 2023-07-24 17:35:24.047179: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-07-24 17:35:24.156654: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 85/85 [==============================] - 10s 55ms/step - loss: 0.0625 - val_loss: 0.0229
# Epoch 2/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0253 - val_loss: 0.0181
# Epoch 3/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0196 - val_loss: 0.0149
# Epoch 4/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0170 - val_loss: 0.0142
# Epoch 5/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0164 - val_loss: 0.0130
# Epoch 6/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0143 - val_loss: 0.0124
# Epoch 7/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0136 - val_loss: 0.0109
# Epoch 8/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0130 - val_loss: 0.0113
# Epoch 9/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0133 - val_loss: 0.0132
# Epoch 10/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0124 - val_loss: 0.0114
# Epoch 11/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0121 - val_loss: 0.0119
# Epoch 12/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0127 - val_loss: 0.0103
# Epoch 13/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0113 - val_loss: 0.0099
# Epoch 14/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0117 - val_loss: 0.0094
# Epoch 15/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0111 - val_loss: 0.0107
# Epoch 16/100
# 85/85 [==============================] - 3s 36ms/step - loss: 0.0108 - val_loss: 0.0098
# Epoch 17/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0109 - val_loss: 0.0105
# Epoch 18/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0107 - val_loss: 0.0090
# Epoch 19/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0112 - val_loss: 0.0107
# Epoch 20/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0100 - val_loss: 0.0090
# Epoch 21/100
# 85/85 [==============================] - 3s 36ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 22/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 23/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0094 - val_loss: 0.0091
# Epoch 24/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0099 - val_loss: 0.0093
# Epoch 25/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0091 - val_loss: 0.0092
# Epoch 26/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0100 - val_loss: 0.0092
# Epoch 27/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0090 - val_loss: 0.0088
# Epoch 28/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0091 - val_loss: 0.0088
# Epoch 29/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0092 - val_loss: 0.0087
# Epoch 30/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0090 - val_loss: 0.0091
# Epoch 31/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0087 - val_loss: 0.0090
# Epoch 32/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0085 - val_loss: 0.0091
# Epoch 33/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0087 - val_loss: 0.0093
# Epoch 34/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0081 - val_loss: 0.0099
# Epoch 35/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0089 - val_loss: 0.0089
# Epoch 36/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0081 - val_loss: 0.0087
# Epoch 37/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0079 - val_loss: 0.0086
# Epoch 38/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0084 - val_loss: 0.0106
# Epoch 39/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0094 - val_loss: 0.0087
# Epoch 40/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0077 - val_loss: 0.0107
# Epoch 41/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0080 - val_loss: 0.0096
# Epoch 42/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0079 - val_loss: 0.0087
# Epoch 43/100
# 85/85 [==============================] - 3s 36ms/step - loss: 0.0077 - val_loss: 0.0085
# Epoch 44/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0074 - val_loss: 0.0087
# Epoch 45/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0076 - val_loss: 0.0084
# Epoch 46/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0074 - val_loss: 0.0085
# Epoch 47/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0082 - val_loss: 0.0086
# Epoch 48/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0074 - val_loss: 0.0083
# Epoch 49/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0072 - val_loss: 0.0089
# Epoch 50/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0070 - val_loss: 0.0091
# Epoch 51/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 52/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0077 - val_loss: 0.0103
# Epoch 53/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0086 - val_loss: 0.0086
# Epoch 54/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0073 - val_loss: 0.0092
# Epoch 55/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0072 - val_loss: 0.0086
# Epoch 56/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0069 - val_loss: 0.0083
# Epoch 57/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 58/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0081 - val_loss: 0.0096
# Epoch 59/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0074 - val_loss: 0.0101
# Epoch 60/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0074 - val_loss: 0.0084
# Epoch 61/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0075 - val_loss: 0.0097
# Epoch 62/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0077 - val_loss: 0.0084
# Epoch 63/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0065 - val_loss: 0.0083
# Epoch 64/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0070 - val_loss: 0.0089
# Epoch 65/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0068 - val_loss: 0.0091
# Epoch 66/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0072 - val_loss: 0.0091
# Epoch 67/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0068 - val_loss: 0.0085
# Epoch 68/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0066 - val_loss: 0.0087
# Epoch 69/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0069 - val_loss: 0.0081
# Epoch 70/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0065 - val_loss: 0.0083
# Epoch 71/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0073 - val_loss: 0.0084
# Epoch 72/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0070 - val_loss: 0.0083
# Epoch 73/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0064 - val_loss: 0.0088
# Epoch 74/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0066 - val_loss: 0.0091
# Epoch 75/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0069 - val_loss: 0.0085
# Epoch 76/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0079 - val_loss: 0.0082
# Epoch 77/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0062 - val_loss: 0.0084
# Epoch 78/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0066 - val_loss: 0.0090
# Epoch 79/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0065 - val_loss: 0.0082
# Epoch 80/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0074 - val_loss: 0.0081
# Epoch 81/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0064 - val_loss: 0.0090
# Epoch 82/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0066 - val_loss: 0.0081
# Epoch 83/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0063 - val_loss: 0.0081
# Epoch 84/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0065 - val_loss: 0.0082
# Epoch 85/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0063 - val_loss: 0.0081
# Epoch 86/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0065 - val_loss: 0.0085
# Epoch 87/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0067 - val_loss: 0.0090
# Epoch 88/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0062 - val_loss: 0.0079
# Epoch 89/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0062 - val_loss: 0.0079
# Epoch 90/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0071 - val_loss: 0.0089
# Epoch 91/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0065 - val_loss: 0.0081
# Epoch 92/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0063 - val_loss: 0.0081
# Epoch 93/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 94/100
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0058 - val_loss: 0.0079
# Epoch 95/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0058 - val_loss: 0.0080
# Epoch 96/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0069 - val_loss: 0.0097
# Epoch 97/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0071 - val_loss: 0.0084
# Epoch 98/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0066 - val_loss: 0.0080
# Epoch 99/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0063 - val_loss: 0.0088
# Epoch 100/100
# 85/85 [==============================] - 3s 35ms/step - loss: 0.0064 - val_loss: 0.0086

# %%
plt.plot(training_loss, label = 'Training loss')
plt.plot(validation_loss, label = 'Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.yscale('log')
plt.legend()
plt.show()

# %%
# Make predictions on the training data
predictions = tf.convert_to_tensor(model.predict(tiles_input))

display_tile_grid([tiles_input, predictions, tiles_expected])
# Out:
# 85/85 [==============================] - 1s 13ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Evaluation

# %%
# Make predictions on the evaluation data
test_predictions = tf.convert_to_tensor(model.predict(validation_tiles_input))

display_tile_grid([validation_tiles_input, test_predictions, validation_tiles_expected], lines_count=4)
# Out:
# 2/2 [==============================] - 0s 90ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
for id in [str(i).zfill(4) for i in range(30, 36)]:
    img = read_image_file('data/output-' + id + '/raw-output-00004-a', geometry_file='data/output-' + id + '/geometry')

    output = model.predict(tf.convert_to_tensor([img]))[0]

    image = Image.fromarray((output * 255).astype(np.uint8))
    image.save('outputs/scene-' + id + '-model-' + MODEL_NAME + '.png')
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step

# %% [markdown]
# ## Save the coefficients

# %%
coefs = []

for layer in model.layers:
    if layer.name[:6] != 'conv2d':
        continue

    weights = layer.weights[0]
    biais = layer.weights[1]

    print(weights.shape, biais.shape)

    coefs += tf.reshape(weights, [int(tf.size(weights))]).numpy().tolist()
    coefs += tf.reshape(biais, [int(tf.size(biais))]).numpy().tolist()

    coefs.append(1)

# Write to the file
output_file = open('models/coefs-' + MODEL_NAME, 'w')

output_file.write(str(len(coefs)) + '\n')

for c in coefs:
    output_file.write(str(c) + ' ')

output_file.close()
# Out:
# (3, 3, 7, 32) (32,)
# (3, 3, 32, 43) (43,)
# (3, 3, 43, 57) (57,)
# (3, 3, 57, 76) (76,)
# (3, 3, 76, 101) (101,)
# (3, 3, 101, 101) (101,)
# (3, 3, 202, 101) (101,)
# (3, 3, 101, 101) (101,)
# (3, 3, 177, 76) (76,)
# (3, 3, 76, 76) (76,)
# (3, 3, 133, 57) (57,)
# (3, 3, 57, 57) (57,)
# (3, 3, 100, 43) (43,)
# (3, 3, 43, 43) (43,)
# (3, 3, 75, 32) (32,)
# (3, 3, 32, 3) (3,)
