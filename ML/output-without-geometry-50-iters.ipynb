# %% [markdown]
# # Denoising Autoencoder

# %% [markdown]
# To start the backend:
# ```
# sudo docker run -it --rm --runtime=nvidia -v $(realpath ~/Documents/ML):/tf/notebooks -p 8888:8888 tensorflow/tensorflow:latest-gpu-jupyter
# ```

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.python.client import device_lib
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
import os

# Needed when using the docker backend
if 'notebooks' in os.listdir():
    os.chdir('notebooks')

# Check if the GPU is detected
local_device_protos = device_lib.list_local_devices()
[x.name for x in local_device_protos]
# Out:
# 2023-07-24 18:27:35.281520: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-24 18:27:35.306799: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-24 18:27:36.240116: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:36.243073: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:36.243154: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:36.288994: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:36.289093: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:36.289144: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:36.289192: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:0 with 5423 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# ['/device:CPU:0', '/device:GPU:0']

# %%
TILE_SIZE = 128
TILES_PER_IMAGE = 30

EPOCHS_COUNT = 50

WITH_GEOMETRY = False

GEOMETRY_CHANNELS_COUNT = 4 if WITH_GEOMETRY else 0
INPUT_CHANNELS_COUNT = 3 + GEOMETRY_CHANNELS_COUNT

MODEL_NAME = str(EPOCHS_COUNT) + '-with' + ('' if WITH_GEOMETRY else 'out') + '-geometry'

# %%
def read_image_file(filename, geometry_file = None):
    WIDTH, HEIGHT = 1024, 1024

    # return tf.constant(np.random.rand(HEIGHT, WIDTH, 3 + (GEOMETRY_CHANNELS_COUNT if geometry_file is not None else 0)), dtype=tf.float16)

    image_data = []
    with open(filename, 'r') as file:
        for line in file:
            values = line.strip().split()
            image_data.append([float(value) for value in values])

    if WITH_GEOMETRY and geometry_file is not None:
        with open(geometry_file, 'r') as file:
            for i, line in enumerate(file):
                values = [float(v) for v in line.strip().split()]
                assert(values[0] <= 100)
                values[0] /= 20 # TODO specific for this scene.. TODO divide by the max
                image_data[i] += values

    image_tensor = tf.constant(image_data, dtype=np.float16)
    image_tensor = tf.reshape(image_tensor, [HEIGHT, WIDTH, 3 + (GEOMETRY_CHANNELS_COUNT if geometry_file is not None else 0)])

    # TODO the file is not stored line by line
    image_tensor = tf.image.rot90(image_tensor)

    return image_tensor


def display_img(img):
    plt.imshow(img.numpy().astype(np.float32)[:,:,:3])
    plt.axis('off')
    plt.show()

# %%
def generate_tiles(img, n, seed=0):
    # return [tf.convert_to_tensor(np.random.rand(TILE_SIZE, TILE_SIZE, len(img[0][0])), dtype=tf.float16) for _ in range(n)]
    return [
        tf.image.stateless_random_flip_left_right(
            tf.image.stateless_random_crop(img, size=(TILE_SIZE, TILE_SIZE, len(img[0][0])), seed=(seed, i)),
            seed=(seed, i)
        )
        for i in range(n)
    ]

def display_tile_grid(tiles, lines_count=4, columns_count=2, size=2):
    fig, axes = plt.subplots(lines_count, columns_count*len(tiles), figsize=(size*columns_count*len(tiles), size*lines_count))

    for i in range(lines_count):
        for j in range(columns_count):
            for k in range(len(tiles)):
                ax = axes[i, j*len(tiles) + k]
                ax.imshow(tiles[k][i*columns_count + j].numpy().astype(np.float32)[:,:,:3])
                ax.axis('off')

    fig.tight_layout()
    plt.show()

# %%
images = []
for i in range(30):
    for c in ['a', 'b', 'c']:
        folder = 'data/output-' + str(i).zfill(4)
        img_input = read_image_file(folder + '/raw-output-00004-' + c, geometry_file = folder + '/geometry')
        img_output = read_image_file(folder + '/raw-output-10000')

        images.append((img_input, img_output))
# Out:
# 2023-07-24 18:27:37.631262: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:37.631387: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:37.631428: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:37.631607: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:37.631655: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:37.631692: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:37.631758: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:37.631798: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:37.631836: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5423 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
display_img(images[0][0])
display_img(images[0][1])

if WITH_GEOMETRY:
    plt.imshow(images[0][0][:,:,3])
    plt.axis('off')
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
tiles_input = []
tiles_expected = []

for i in range(30):
    for j in range(3):
        img_input, img_expected = images[i*3 + j]

        tiles_input += generate_tiles(img_input, TILES_PER_IMAGE, seed=i)
        tiles_expected += generate_tiles(img_expected, TILES_PER_IMAGE, seed=i)

tiles_input, tiles_expected = tf.convert_to_tensor(tiles_input), tf.convert_to_tensor(tiles_expected)

display_tile_grid([tiles_input, tiles_expected])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Validation
validation_images = []
for i in range(34, 36):
    for c in ['a']:
        folder = 'data/output-' + str(i).zfill(4)
        img_input = read_image_file(folder + '/raw-output-00004-' + c, geometry_file = folder + '/geometry')
        img_output = read_image_file(folder + '/raw-output-10000')

        validation_images.append((img_input, img_output))

validation_tiles_input = []
validation_tiles_expected = []

for img_input, img_expected in validation_images:
    validation_tiles_input += generate_tiles(img_input, TILES_PER_IMAGE)
    validation_tiles_expected += generate_tiles(img_expected, TILES_PER_IMAGE)

validation_tiles_input, validation_tiles_expected = tf.convert_to_tensor(validation_tiles_input), tf.convert_to_tensor(validation_tiles_expected)

# %% [markdown]
# ## CNN

# %%
input_shape = (None, None, INPUT_CHANNELS_COUNT)

inputs = tf.keras.Input(shape=input_shape)

x_128 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)

x_64 = layers.MaxPooling2D((2, 2))(x_128)
x_64 = layers.Conv2D(43, (3, 3), activation='relu', padding='same')(x_64)

x_32 = layers.MaxPooling2D((2, 2))(x_64)
x_32 = layers.Conv2D(57, (3, 3), activation='relu', padding='same')(x_32)

x_16 = layers.MaxPooling2D((2, 2))(x_32)
x_16 = layers.Conv2D(76, (3, 3), activation='relu', padding='same')(x_16)

x_8 = layers.MaxPooling2D((2, 2))(x_16)
x_8 = layers.Conv2D(101, (3, 3), activation='relu', padding='same')(x_8)

x_4 = layers.MaxPooling2D((2, 2))(x_8)
x_4 = layers.Conv2D(101, (3, 3), activation='relu', padding='same')(x_4)

x = layers.UpSampling2D(size=(2, 2))(x_4)
x = layers.Concatenate()([x, x_8]) # Skip connection
x = layers.Conv2D(101, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(101, (3, 3), activation='relu', padding='same')(x)

x = layers.UpSampling2D(size=(2, 2))(x)
x = layers.Concatenate()([x, x_16]) # Skip connection
x = layers.Conv2D(76, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(76, (3, 3), activation='relu', padding='same')(x)

x = layers.UpSampling2D(size=(2, 2))(x)
x = layers.Concatenate()([x, x_32]) # Skip connection
x = layers.Conv2D(57, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(57, (3, 3), activation='relu', padding='same')(x)

x = layers.UpSampling2D(size=(2, 2))(x)
x = layers.Concatenate()([x, x_64]) # Skip connection
x = layers.Conv2D(43, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(43, (3, 3), activation='relu', padding='same')(x)

x = layers.UpSampling2D(size=(2, 2))(x)
x = layers.Concatenate()([x, x_128]) # Skip connection
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(3, (3, 3), activation='relu', padding='same')(x)

outputs = x

# Create the model
model = tf.keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='mean_absolute_error')

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  conv2d_16 (Conv2D)          (None, None, None, 32)       896       ['input_2[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, None, None, 32)       0         ['conv2d_16[0][0]']
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, None, None, 43)       12427     ['max_pooling2d_5[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, None, None, 43)       0         ['conv2d_17[0][0]']
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, None, None, 57)       22116     ['max_pooling2d_6[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, None, None, 57)       0         ['conv2d_18[0][0]']
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, None, None, 76)       39064     ['max_pooling2d_7[0][0]']
#
#  max_pooling2d_8 (MaxPoolin  (None, None, None, 76)       0         ['conv2d_19[0][0]']
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, None, None, 101)      69185     ['max_pooling2d_8[0][0]']
#
#  max_pooling2d_9 (MaxPoolin  (None, None, None, 101)      0         ['conv2d_20[0][0]']
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, None, None, 101)      91910     ['max_pooling2d_9[0][0]']
#
#  up_sampling2d_5 (UpSamplin  (None, None, None, 101)      0         ['conv2d_21[0][0]']
#  g2D)
#
#  concatenate_5 (Concatenate  (None, None, None, 202)      0         ['up_sampling2d_5[0][0]',
#  )                                                                   'conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)          (None, None, None, 101)      183719    ['concatenate_5[0][0]']
#
#  conv2d_23 (Conv2D)          (None, None, None, 101)      91910     ['conv2d_22[0][0]']
#
#  up_sampling2d_6 (UpSamplin  (None, None, None, 101)      0         ['conv2d_23[0][0]']
#  g2D)
#
#  concatenate_6 (Concatenate  (None, None, None, 177)      0         ['up_sampling2d_6[0][0]',
#  )                                                                   'conv2d_19[0][0]']
#
#  conv2d_24 (Conv2D)          (None, None, None, 76)       121144    ['concatenate_6[0][0]']
#
#  conv2d_25 (Conv2D)          (None, None, None, 76)       52060     ['conv2d_24[0][0]']
#
#  up_sampling2d_7 (UpSamplin  (None, None, None, 76)       0         ['conv2d_25[0][0]']
#  g2D)
#
#  concatenate_7 (Concatenate  (None, None, None, 133)      0         ['up_sampling2d_7[0][0]',
#  )                                                                   'conv2d_18[0][0]']
#
#  conv2d_26 (Conv2D)          (None, None, None, 57)       68286     ['concatenate_7[0][0]']
#
#  conv2d_27 (Conv2D)          (None, None, None, 57)       29298     ['conv2d_26[0][0]']
#
#  up_sampling2d_8 (UpSamplin  (None, None, None, 57)       0         ['conv2d_27[0][0]']
#  g2D)
#
#  concatenate_8 (Concatenate  (None, None, None, 100)      0         ['up_sampling2d_8[0][0]',
#  )                                                                   'conv2d_17[0][0]']
#
#  conv2d_28 (Conv2D)          (None, None, None, 43)       38743     ['concatenate_8[0][0]']
#
#  conv2d_29 (Conv2D)          (None, None, None, 43)       16684     ['conv2d_28[0][0]']
#
#  up_sampling2d_9 (UpSamplin  (None, None, None, 43)       0         ['conv2d_29[0][0]']
#  g2D)
#
#  concatenate_9 (Concatenate  (None, None, None, 75)       0         ['up_sampling2d_9[0][0]',
#  )                                                                   'conv2d_16[0][0]']
#
#  conv2d_30 (Conv2D)          (None, None, None, 32)       21632     ['concatenate_9[0][0]']
#
#  conv2d_31 (Conv2D)          (None, None, None, 3)        867       ['conv2d_30[0][0]']
#
# ==================================================================================================
# Total params: 859941 (3.28 MB)
# Trainable params: 859941 (3.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Train the model if needed
if os.path.isfile('models/' + MODEL_NAME + '.index'):
    model.load_weights('models/' + MODEL_NAME)
else:
    hist = model.fit(tiles_input, tiles_expected, epochs=EPOCHS_COUNT, validation_data=(validation_tiles_input, validation_tiles_expected))

    training_loss = hist.history['loss']
    validation_loss = hist.history['val_loss']

    model.save_weights('models/' + MODEL_NAME)
# Out:
# Epoch 1/50
# 85/85 [==============================] - 5s 33ms/step - loss: 0.0373 - val_loss: 0.0178
# Epoch 2/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0204 - val_loss: 0.0140
# Epoch 3/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0169 - val_loss: 0.0130
# Epoch 4/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0149 - val_loss: 0.0117
# Epoch 5/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0140 - val_loss: 0.0106
# Epoch 6/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0129 - val_loss: 0.0113
# Epoch 7/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0130 - val_loss: 0.0102
# Epoch 8/50
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0132 - val_loss: 0.0102
# Epoch 9/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0116 - val_loss: 0.0096
# Epoch 10/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0112 - val_loss: 0.0097
# Epoch 11/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0117 - val_loss: 0.0100
# Epoch 12/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0110 - val_loss: 0.0099
# Epoch 13/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0108 - val_loss: 0.0099
# Epoch 14/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0106 - val_loss: 0.0104
# Epoch 15/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0109 - val_loss: 0.0096
# Epoch 16/50
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0101 - val_loss: 0.0100
# Epoch 17/50
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0099 - val_loss: 0.0094
# Epoch 18/50
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0101 - val_loss: 0.0103
# Epoch 19/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0102 - val_loss: 0.0130
# Epoch 20/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0097 - val_loss: 0.0090
# Epoch 21/50
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0094 - val_loss: 0.0099
# Epoch 22/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0097 - val_loss: 0.0097
# Epoch 23/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0094 - val_loss: 0.0097
# Epoch 24/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0093 - val_loss: 0.0093
# Epoch 25/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0089 - val_loss: 0.0107
# Epoch 26/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0090 - val_loss: 0.0102
# Epoch 27/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0093 - val_loss: 0.0098
# Epoch 28/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0092 - val_loss: 0.0092
# Epoch 29/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0086 - val_loss: 0.0091
# Epoch 30/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0085 - val_loss: 0.0092
# Epoch 31/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0089 - val_loss: 0.0101
# Epoch 32/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0083 - val_loss: 0.0094
# Epoch 33/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 34/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0083 - val_loss: 0.0090
# Epoch 35/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0080 - val_loss: 0.0095
# Epoch 36/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0079 - val_loss: 0.0092
# Epoch 37/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0086 - val_loss: 0.0093
# Epoch 38/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0076 - val_loss: 0.0093
# Epoch 39/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0080 - val_loss: 0.0098
# Epoch 40/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0080 - val_loss: 0.0099
# Epoch 41/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0078 - val_loss: 0.0096
# Epoch 42/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0076 - val_loss: 0.0110
# Epoch 43/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0080 - val_loss: 0.0095
# Epoch 44/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0081 - val_loss: 0.0095
# Epoch 45/50
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0079 - val_loss: 0.0090
# Epoch 46/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0073 - val_loss: 0.0093
# Epoch 47/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0075 - val_loss: 0.0093
# Epoch 48/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0075 - val_loss: 0.0093
# Epoch 49/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 50/50
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0085 - val_loss: 0.0094

# %%
xs = range(10, len(training_loss))
plt.plot(xs, training_loss[10:], label = 'Training loss')
plt.plot(xs, validation_loss[10:], label = 'Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.yscale('log')
plt.legend()
plt.show()

# %%
# Make predictions on the training data
predictions = tf.convert_to_tensor(model.predict(tiles_input))

display_tile_grid([tiles_input, predictions, tiles_expected])
# Out:
# 85/85 [==============================] - 1s 11ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Evaluation

# %%
# Make predictions on the evaluation data
test_predictions = tf.convert_to_tensor(model.predict(validation_tiles_input))

display_tile_grid([validation_tiles_input, test_predictions, validation_tiles_expected], lines_count=4)
# Out:
# 2/2 [==============================] - 0s 11ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
for id in [str(i).zfill(4) for i in range(30, 36)]:
    img = read_image_file('data/output-' + id + '/raw-output-00004-a', geometry_file='data/output-' + id + '/geometry')

    output = model.predict(tf.convert_to_tensor([img]))[0]

    image = Image.fromarray((output * 255).astype(np.uint8))
    image.save('outputs/scene-' + id + '-model-' + MODEL_NAME + '.png')
# Out:
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step

# %% [markdown]
# ## Save the coefficients

# %%
coefs = []

for layer in model.layers:
    if layer.name[:6] != 'conv2d':
        continue

    weights = layer.weights[0]
    biais = layer.weights[1]

    print(weights.shape, biais.shape)

    coefs += tf.reshape(weights, [int(tf.size(weights))]).numpy().tolist()
    coefs += tf.reshape(biais, [int(tf.size(biais))]).numpy().tolist()

    coefs.append(1)

# Write to the file
output_file = open('models/coefs-' + MODEL_NAME, 'w')

output_file.write(str(len(coefs)) + '\n')

for c in coefs:
    output_file.write(str(c) + ' ')

output_file.close()
# Out:
# (3, 3, 3, 32) (32,)
# (3, 3, 32, 43) (43,)
# (3, 3, 43, 57) (57,)
# (3, 3, 57, 76) (76,)
# (3, 3, 76, 101) (101,)
# (3, 3, 101, 101) (101,)
# (3, 3, 202, 101) (101,)
# (3, 3, 101, 101) (101,)
# (3, 3, 177, 76) (76,)
# (3, 3, 76, 76) (76,)
# (3, 3, 133, 57) (57,)
# (3, 3, 57, 57) (57,)
# (3, 3, 100, 43) (43,)
# (3, 3, 43, 43) (43,)
# (3, 3, 75, 32) (32,)
# (3, 3, 32, 3) (3,)
