# %% [markdown]
# # Denoising Autoencoder

# %% [markdown]
# To start the backend:
# ```
# sudo docker run -it --rm --runtime=nvidia -v $(realpath ~/Documents/ML):/tf/notebooks -p 8888:8888 tensorflow/tensorflow:latest-gpu-jupyter
# ```

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.python.client import device_lib
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
import os

# Needed when using the docker backend
if 'notebooks' in os.listdir():
    os.chdir('notebooks')

# Check if the GPU is detected
local_device_protos = device_lib.list_local_devices()
[x.name for x in local_device_protos]
# Out:
# 2023-07-24 18:27:35.281520: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-24 18:27:35.306799: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-24 18:27:36.240116: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:36.243073: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:36.243154: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:36.288994: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:36.289093: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:36.289144: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:36.289192: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:0 with 5423 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# ['/device:CPU:0', '/device:GPU:0']

# %%
TILE_SIZE = 128
TILES_PER_IMAGE = 30

EPOCHS_COUNT = 200

WITH_GEOMETRY = False

GEOMETRY_CHANNELS_COUNT = 4 if WITH_GEOMETRY else 0
INPUT_CHANNELS_COUNT = 3 + GEOMETRY_CHANNELS_COUNT

MODEL_NAME = str(EPOCHS_COUNT) + '-with' + ('' if WITH_GEOMETRY else 'out') + '-geometry'

# %%
def read_image_file(filename, geometry_file = None):
    WIDTH, HEIGHT = 1024, 1024

    # return tf.constant(np.random.rand(HEIGHT, WIDTH, 3 + (GEOMETRY_CHANNELS_COUNT if geometry_file is not None else 0)), dtype=tf.float16)

    image_data = []
    with open(filename, 'r') as file:
        for line in file:
            values = line.strip().split()
            image_data.append([float(value) for value in values])

    if WITH_GEOMETRY and geometry_file is not None:
        with open(geometry_file, 'r') as file:
            for i, line in enumerate(file):
                values = [float(v) for v in line.strip().split()]
                assert(values[0] <= 100)
                values[0] /= 20 # TODO specific for this scene.. TODO divide by the max
                image_data[i] += values

    image_tensor = tf.constant(image_data, dtype=np.float16)
    image_tensor = tf.reshape(image_tensor, [HEIGHT, WIDTH, 3 + (GEOMETRY_CHANNELS_COUNT if geometry_file is not None else 0)])

    # TODO the file is not stored line by line
    image_tensor = tf.image.rot90(image_tensor)

    return image_tensor


def display_img(img):
    plt.imshow(img.numpy().astype(np.float32)[:,:,:3])
    plt.axis('off')
    plt.show()

# %%
def generate_tiles(img, n, seed=0):
    # return [tf.convert_to_tensor(np.random.rand(TILE_SIZE, TILE_SIZE, len(img[0][0])), dtype=tf.float16) for _ in range(n)]
    return [
        tf.image.stateless_random_flip_left_right(
            tf.image.stateless_random_crop(img, size=(TILE_SIZE, TILE_SIZE, len(img[0][0])), seed=(seed, i)),
            seed=(seed, i)
        )
        for i in range(n)
    ]

def display_tile_grid(tiles, lines_count=4, columns_count=2, size=2):
    fig, axes = plt.subplots(lines_count, columns_count*len(tiles), figsize=(size*columns_count*len(tiles), size*lines_count))

    for i in range(lines_count):
        for j in range(columns_count):
            for k in range(len(tiles)):
                ax = axes[i, j*len(tiles) + k]
                ax.imshow(tiles[k][i*columns_count + j].numpy().astype(np.float32)[:,:,:3])
                ax.axis('off')

    fig.tight_layout()
    plt.show()

# %%
images = []
for i in range(30):
    for c in ['a', 'b', 'c']:
        folder = 'data/output-' + str(i).zfill(4)
        img_input = read_image_file(folder + '/raw-output-00004-' + c, geometry_file = folder + '/geometry')
        img_output = read_image_file(folder + '/raw-output-10000')

        images.append((img_input, img_output))
# Out:
# 2023-07-24 18:27:37.631262: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:37.631387: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:37.631428: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:37.631607: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:37.631655: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:37.631692: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:37.631758: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:37.631798: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-24 18:27:37.631836: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5423 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
display_img(images[0][0])
display_img(images[0][1])

if WITH_GEOMETRY:
    plt.imshow(images[0][0][:,:,3])
    plt.axis('off')
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
tiles_input = []
tiles_expected = []

for i in range(30):
    for j in range(3):
        img_input, img_expected = images[i*3 + j]

        tiles_input += generate_tiles(img_input, TILES_PER_IMAGE, seed=i)
        tiles_expected += generate_tiles(img_expected, TILES_PER_IMAGE, seed=i)

tiles_input, tiles_expected = tf.convert_to_tensor(tiles_input), tf.convert_to_tensor(tiles_expected)

display_tile_grid([tiles_input, tiles_expected])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Validation
validation_images = []
for i in range(34, 36):
    for c in ['a']:
        folder = 'data/output-' + str(i).zfill(4)
        img_input = read_image_file(folder + '/raw-output-00004-' + c, geometry_file = folder + '/geometry')
        img_output = read_image_file(folder + '/raw-output-10000')

        validation_images.append((img_input, img_output))

validation_tiles_input = []
validation_tiles_expected = []

for img_input, img_expected in validation_images:
    validation_tiles_input += generate_tiles(img_input, TILES_PER_IMAGE)
    validation_tiles_expected += generate_tiles(img_expected, TILES_PER_IMAGE)

validation_tiles_input, validation_tiles_expected = tf.convert_to_tensor(validation_tiles_input), tf.convert_to_tensor(validation_tiles_expected)

# %% [markdown]
# ## CNN

# %%
input_shape = (None, None, INPUT_CHANNELS_COUNT)

inputs = tf.keras.Input(shape=input_shape)

x_128 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)

x_64 = layers.MaxPooling2D((2, 2))(x_128)
x_64 = layers.Conv2D(43, (3, 3), activation='relu', padding='same')(x_64)

x_32 = layers.MaxPooling2D((2, 2))(x_64)
x_32 = layers.Conv2D(57, (3, 3), activation='relu', padding='same')(x_32)

x_16 = layers.MaxPooling2D((2, 2))(x_32)
x_16 = layers.Conv2D(76, (3, 3), activation='relu', padding='same')(x_16)

x_8 = layers.MaxPooling2D((2, 2))(x_16)
x_8 = layers.Conv2D(101, (3, 3), activation='relu', padding='same')(x_8)

x_4 = layers.MaxPooling2D((2, 2))(x_8)
x_4 = layers.Conv2D(101, (3, 3), activation='relu', padding='same')(x_4)

x = layers.UpSampling2D(size=(2, 2))(x_4)
x = layers.Concatenate()([x, x_8]) # Skip connection
x = layers.Conv2D(101, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(101, (3, 3), activation='relu', padding='same')(x)

x = layers.UpSampling2D(size=(2, 2))(x)
x = layers.Concatenate()([x, x_16]) # Skip connection
x = layers.Conv2D(76, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(76, (3, 3), activation='relu', padding='same')(x)

x = layers.UpSampling2D(size=(2, 2))(x)
x = layers.Concatenate()([x, x_32]) # Skip connection
x = layers.Conv2D(57, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(57, (3, 3), activation='relu', padding='same')(x)

x = layers.UpSampling2D(size=(2, 2))(x)
x = layers.Concatenate()([x, x_64]) # Skip connection
x = layers.Conv2D(43, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(43, (3, 3), activation='relu', padding='same')(x)

x = layers.UpSampling2D(size=(2, 2))(x)
x = layers.Concatenate()([x, x_128]) # Skip connection
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(3, (3, 3), activation='relu', padding='same')(x)

outputs = x

# Create the model
model = tf.keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='mean_absolute_error')

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  conv2d (Conv2D)             (None, None, None, 32)       896       ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, None, None, 32)       0         ['conv2d[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, None, None, 43)       12427     ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, None, None, 43)       0         ['conv2d_1[0][0]']
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, None, None, 57)       22116     ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, None, None, 57)       0         ['conv2d_2[0][0]']
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, None, None, 76)       39064     ['max_pooling2d_2[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, None, None, 76)       0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, None, None, 101)      69185     ['max_pooling2d_3[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, None, None, 101)      0         ['conv2d_4[0][0]']
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, None, None, 101)      91910     ['max_pooling2d_4[0][0]']
#
#  up_sampling2d (UpSampling2  (None, None, None, 101)      0         ['conv2d_5[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, None, None, 202)      0         ['up_sampling2d[0][0]',
#                                                                      'conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)           (None, None, None, 101)      183719    ['concatenate[0][0]']
#
#  conv2d_7 (Conv2D)           (None, None, None, 101)      91910     ['conv2d_6[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, None, None, 101)      0         ['conv2d_7[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, None, None, 177)      0         ['up_sampling2d_1[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_8 (Conv2D)           (None, None, None, 76)       121144    ['concatenate_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, None, None, 76)       52060     ['conv2d_8[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, None, None, 76)       0         ['conv2d_9[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, None, None, 133)      0         ['up_sampling2d_2[0][0]',
#  )                                                                   'conv2d_2[0][0]']
#
#  conv2d_10 (Conv2D)          (None, None, None, 57)       68286     ['concatenate_2[0][0]']
#
#  conv2d_11 (Conv2D)          (None, None, None, 57)       29298     ['conv2d_10[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, None, None, 57)       0         ['conv2d_11[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, None, None, 100)      0         ['up_sampling2d_3[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_12 (Conv2D)          (None, None, None, 43)       38743     ['concatenate_3[0][0]']
#
#  conv2d_13 (Conv2D)          (None, None, None, 43)       16684     ['conv2d_12[0][0]']
#
#  up_sampling2d_4 (UpSamplin  (None, None, None, 43)       0         ['conv2d_13[0][0]']
#  g2D)
#
#  concatenate_4 (Concatenate  (None, None, None, 75)       0         ['up_sampling2d_4[0][0]',
#  )                                                                   'conv2d[0][0]']
#
#  conv2d_14 (Conv2D)          (None, None, None, 32)       21632     ['concatenate_4[0][0]']
#
#  conv2d_15 (Conv2D)          (None, None, None, 3)        867       ['conv2d_14[0][0]']
#
# ==================================================================================================
# Total params: 859941 (3.28 MB)
# Trainable params: 859941 (3.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Train the model if needed
if os.path.isfile('models/' + MODEL_NAME + '.index'):
    model.load_weights('models/' + MODEL_NAME)
else:
    hist = model.fit(tiles_input, tiles_expected, epochs=EPOCHS_COUNT, validation_data=(validation_tiles_input, validation_tiles_expected))

    training_loss = hist.history['loss']
    validation_loss = hist.history['val_loss']

    model.save_weights('models/' + MODEL_NAME)
# Out:
# Epoch 1/200
# 2023-07-24 18:31:29.118542: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-07-24 18:31:29.818909: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x751b4c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-07-24 18:31:29.818937: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3070 Ti, Compute Capability 8.6
# 2023-07-24 18:31:29.821758: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-07-24 18:31:29.887391: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 85/85 [==============================] - 10s 53ms/step - loss: 0.0428 - val_loss: 0.0189
# Epoch 2/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0196 - val_loss: 0.0136
# Epoch 3/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0163 - val_loss: 0.0123
# Epoch 4/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0148 - val_loss: 0.0142
# Epoch 5/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0144 - val_loss: 0.0115
# Epoch 6/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0135 - val_loss: 0.0104
# Epoch 7/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0126 - val_loss: 0.0105
# Epoch 8/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0122 - val_loss: 0.0103
# Epoch 9/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0121 - val_loss: 0.0109
# Epoch 10/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0118 - val_loss: 0.0101
# Epoch 11/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0115 - val_loss: 0.0103
# Epoch 12/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0112 - val_loss: 0.0099
# Epoch 13/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0112 - val_loss: 0.0099
# Epoch 14/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0111 - val_loss: 0.0093
# Epoch 15/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0107 - val_loss: 0.0093
# Epoch 16/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0104 - val_loss: 0.0093
# Epoch 17/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0104 - val_loss: 0.0092
# Epoch 18/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0102 - val_loss: 0.0090
# Epoch 19/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0100 - val_loss: 0.0092
# Epoch 20/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 21/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0098 - val_loss: 0.0097
# Epoch 22/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0097 - val_loss: 0.0097
# Epoch 23/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0096 - val_loss: 0.0096
# Epoch 24/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0095 - val_loss: 0.0092
# Epoch 25/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0095 - val_loss: 0.0090
# Epoch 26/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0089 - val_loss: 0.0094
# Epoch 27/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0089 - val_loss: 0.0097
# Epoch 28/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0093 - val_loss: 0.0090
# Epoch 29/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0088 - val_loss: 0.0091
# Epoch 30/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0087 - val_loss: 0.0094
# Epoch 31/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0095 - val_loss: 0.0090
# Epoch 32/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0084 - val_loss: 0.0090
# Epoch 33/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0085 - val_loss: 0.0104
# Epoch 34/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0086 - val_loss: 0.0094
# Epoch 35/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0079 - val_loss: 0.0091
# Epoch 36/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0083 - val_loss: 0.0091
# Epoch 37/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 38/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0079 - val_loss: 0.0089
# Epoch 39/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0081 - val_loss: 0.0093
# Epoch 40/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0087 - val_loss: 0.0090
# Epoch 41/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0084 - val_loss: 0.0091
# Epoch 42/200
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0081 - val_loss: 0.0091
# Epoch 43/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0079 - val_loss: 0.0104
# Epoch 44/200
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0079 - val_loss: 0.0090
# Epoch 45/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 46/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0077 - val_loss: 0.0090
# Epoch 47/200
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0080 - val_loss: 0.0100
# Epoch 48/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0083 - val_loss: 0.0089
# Epoch 49/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0074 - val_loss: 0.0091
# Epoch 50/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0082 - val_loss: 0.0089
# Epoch 51/200
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0074 - val_loss: 0.0094
# Epoch 52/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0078 - val_loss: 0.0092
# Epoch 53/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0073 - val_loss: 0.0094
# Epoch 54/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 55/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0075 - val_loss: 0.0093
# Epoch 56/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0074 - val_loss: 0.0114
# Epoch 57/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0080 - val_loss: 0.0090
# Epoch 58/200
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 59/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0069 - val_loss: 0.0089
# Epoch 60/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0068 - val_loss: 0.0090
# Epoch 61/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0067 - val_loss: 0.0091
# Epoch 62/200
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0068 - val_loss: 0.0094
# Epoch 63/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0080 - val_loss: 0.0095
# Epoch 64/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0076 - val_loss: 0.0091
# Epoch 65/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0068 - val_loss: 0.0092
# Epoch 66/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0068 - val_loss: 0.0091
# Epoch 67/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0075 - val_loss: 0.0092
# Epoch 68/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0069 - val_loss: 0.0089
# Epoch 69/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0068 - val_loss: 0.0091
# Epoch 70/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0071 - val_loss: 0.0092
# Epoch 71/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0071 - val_loss: 0.0092
# Epoch 72/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0065 - val_loss: 0.0090
# Epoch 73/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0064 - val_loss: 0.0090
# Epoch 74/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0072 - val_loss: 0.0092
# Epoch 75/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0073 - val_loss: 0.0094
# Epoch 76/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0072 - val_loss: 0.0095
# Epoch 77/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0066 - val_loss: 0.0089
# Epoch 78/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0065 - val_loss: 0.0089
# Epoch 79/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0065 - val_loss: 0.0092
# Epoch 80/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0065 - val_loss: 0.0092
# Epoch 81/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0066 - val_loss: 0.0090
# Epoch 82/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0067 - val_loss: 0.0095
# Epoch 83/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0073 - val_loss: 0.0091
# Epoch 84/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0067 - val_loss: 0.0095
# Epoch 85/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 86/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0065 - val_loss: 0.0092
# Epoch 87/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0072 - val_loss: 0.0095
# Epoch 88/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0064 - val_loss: 0.0099
# Epoch 89/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0067 - val_loss: 0.0092
# Epoch 90/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0070 - val_loss: 0.0093
# Epoch 91/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0065 - val_loss: 0.0092
# Epoch 92/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0065 - val_loss: 0.0089
# Epoch 93/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0065 - val_loss: 0.0088
# Epoch 94/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0063 - val_loss: 0.0092
# Epoch 95/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0062 - val_loss: 0.0089
# Epoch 96/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0071 - val_loss: 0.0101
# Epoch 97/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0070 - val_loss: 0.0100
# Epoch 98/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0063 - val_loss: 0.0089
# Epoch 99/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0062 - val_loss: 0.0090
# Epoch 100/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0063 - val_loss: 0.0094
# Epoch 101/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0067 - val_loss: 0.0091
# Epoch 102/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0064 - val_loss: 0.0090
# Epoch 103/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0060 - val_loss: 0.0088
# Epoch 104/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0059 - val_loss: 0.0093
# Epoch 105/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0064 - val_loss: 0.0090
# Epoch 106/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0063 - val_loss: 0.0091
# Epoch 107/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0064 - val_loss: 0.0089
# Epoch 108/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0061 - val_loss: 0.0090
# Epoch 109/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0061 - val_loss: 0.0090
# Epoch 110/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0066 - val_loss: 0.0094
# Epoch 111/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0068 - val_loss: 0.0096
# Epoch 112/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0066 - val_loss: 0.0101
# Epoch 113/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0063 - val_loss: 0.0089
# Epoch 114/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0059 - val_loss: 0.0089
# Epoch 115/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0059 - val_loss: 0.0091
# Epoch 116/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0066 - val_loss: 0.0095
# Epoch 117/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0073 - val_loss: 0.0094
# Epoch 118/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0065 - val_loss: 0.0090
# Epoch 119/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0059 - val_loss: 0.0092
# Epoch 120/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0060 - val_loss: 0.0091
# Epoch 121/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0062 - val_loss: 0.0091
# Epoch 122/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0063 - val_loss: 0.0096
# Epoch 123/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0062 - val_loss: 0.0092
# Epoch 124/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0061 - val_loss: 0.0089
# Epoch 125/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0060 - val_loss: 0.0089
# Epoch 126/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0061 - val_loss: 0.0093
# Epoch 127/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0063 - val_loss: 0.0089
# Epoch 128/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0064 - val_loss: 0.0091
# Epoch 129/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0062 - val_loss: 0.0090
# Epoch 130/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0057 - val_loss: 0.0104
# Epoch 131/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0067 - val_loss: 0.0091
# Epoch 132/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0060 - val_loss: 0.0090
# Epoch 133/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0058 - val_loss: 0.0089
# Epoch 134/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0059 - val_loss: 0.0090
# Epoch 135/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0063 - val_loss: 0.0091
# Epoch 136/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0058 - val_loss: 0.0094
# Epoch 137/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0062 - val_loss: 0.0089
# Epoch 138/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0059 - val_loss: 0.0093
# Epoch 139/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0060 - val_loss: 0.0100
# Epoch 140/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0068 - val_loss: 0.0089
# Epoch 141/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0061 - val_loss: 0.0089
# Epoch 142/200
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0060 - val_loss: 0.0091
# Epoch 143/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0060 - val_loss: 0.0090
# Epoch 144/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0059 - val_loss: 0.0092
# Epoch 145/200
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0059 - val_loss: 0.0090
# Epoch 146/200
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0061 - val_loss: 0.0094
# Epoch 147/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0066 - val_loss: 0.0091
# Epoch 148/200
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0058 - val_loss: 0.0091
# Epoch 149/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0059 - val_loss: 0.0091
# Epoch 150/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0058 - val_loss: 0.0089
# Epoch 151/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0062 - val_loss: 0.0089
# Epoch 152/200
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0067 - val_loss: 0.0090
# Epoch 153/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0058 - val_loss: 0.0089
# Epoch 154/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0067 - val_loss: 0.0102
# Epoch 155/200
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0063 - val_loss: 0.0091
# Epoch 156/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0059 - val_loss: 0.0096
# Epoch 157/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0060 - val_loss: 0.0089
# Epoch 158/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0063 - val_loss: 0.0096
# Epoch 159/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0066 - val_loss: 0.0090
# Epoch 160/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0058 - val_loss: 0.0089
# Epoch 161/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0059 - val_loss: 0.0090
# Epoch 162/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0057 - val_loss: 0.0089
# Epoch 163/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0056 - val_loss: 0.0090
# Epoch 164/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0057 - val_loss: 0.0090
# Epoch 165/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0058 - val_loss: 0.0089
# Epoch 166/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0059 - val_loss: 0.0093
# Epoch 167/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0058 - val_loss: 0.0090
# Epoch 168/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0068 - val_loss: 0.0094
# Epoch 169/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0067 - val_loss: 0.0091
# Epoch 170/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0057 - val_loss: 0.0089
# Epoch 171/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0056 - val_loss: 0.0095
# Epoch 172/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0058 - val_loss: 0.0090
# Epoch 173/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0058 - val_loss: 0.0093
# Epoch 174/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0061 - val_loss: 0.0088
# Epoch 175/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0058 - val_loss: 0.0089
# Epoch 176/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0056 - val_loss: 0.0092
# Epoch 177/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0062 - val_loss: 0.0106
# Epoch 178/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0062 - val_loss: 0.0091
# Epoch 179/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0059 - val_loss: 0.0089
# Epoch 180/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0056 - val_loss: 0.0092
# Epoch 181/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0058 - val_loss: 0.0090
# Epoch 182/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0059 - val_loss: 0.0093
# Epoch 183/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0063 - val_loss: 0.0089
# Epoch 184/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0061 - val_loss: 0.0089
# Epoch 185/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0056 - val_loss: 0.0089
# Epoch 186/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0057 - val_loss: 0.0088
# Epoch 187/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0059 - val_loss: 0.0091
# Epoch 188/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0060 - val_loss: 0.0088
# Epoch 189/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0056 - val_loss: 0.0091
# Epoch 190/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0056 - val_loss: 0.0088
# Epoch 191/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0056 - val_loss: 0.0095
# Epoch 192/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0058 - val_loss: 0.0091
# Epoch 193/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0056 - val_loss: 0.0091
# Epoch 194/200
# 85/85 [==============================] - 3s 34ms/step - loss: 0.0063 - val_loss: 0.0094
# Epoch 195/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0058 - val_loss: 0.0088
# Epoch 196/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0056 - val_loss: 0.0089
# Epoch 197/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0056 - val_loss: 0.0089
# Epoch 198/200
# 85/85 [==============================] - 3s 33ms/step - loss: 0.0057 - val_loss: 0.0090
# Epoch 199/200
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0060 - val_loss: 0.0090
# Epoch 200/200
# 85/85 [==============================] - 3s 32ms/step - loss: 0.0059 - val_loss: 0.0090

# %%
xs = range(10, len(training_loss))
plt.plot(xs, training_loss[10:], label = 'Training loss')
plt.plot(xs, validation_loss[10:], label = 'Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.yscale('log')
plt.legend()
plt.show()

# %%
# Make predictions on the training data
predictions = tf.convert_to_tensor(model.predict(tiles_input))

display_tile_grid([tiles_input, predictions, tiles_expected])
# Out:
# 85/85 [==============================] - 1s 11ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Evaluation

# %%
# Make predictions on the evaluation data
test_predictions = tf.convert_to_tensor(model.predict(validation_tiles_input))

display_tile_grid([validation_tiles_input, test_predictions, validation_tiles_expected], lines_count=4)
# Out:
# 2/2 [==============================] - 0s 89ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
for id in [str(i).zfill(4) for i in range(30, 36)]:
    img = read_image_file('data/output-' + id + '/raw-output-00004-a', geometry_file='data/output-' + id + '/geometry')

    output = model.predict(tf.convert_to_tensor([img]))[0]

    image = Image.fromarray((output * 255).astype(np.uint8))
    image.save('outputs/scene-' + id + '-model-' + MODEL_NAME + '.png')
# Out:
# 1/1 [==============================] - 0s 466ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step

# %% [markdown]
# ## Save the coefficients

# %%
coefs = []

for layer in model.layers:
    if layer.name[:6] != 'conv2d':
        continue

    weights = layer.weights[0]
    biais = layer.weights[1]

    print(weights.shape, biais.shape)

    coefs += tf.reshape(weights, [int(tf.size(weights))]).numpy().tolist()
    coefs += tf.reshape(biais, [int(tf.size(biais))]).numpy().tolist()

    coefs.append(1)

# Write to the file
output_file = open('models/coefs-' + MODEL_NAME, 'w')

output_file.write(str(len(coefs)) + '\n')

for c in coefs:
    output_file.write(str(c) + ' ')

output_file.close()
# Out:
# (3, 3, 3, 32) (32,)
# (3, 3, 32, 43) (43,)
# (3, 3, 43, 57) (57,)
# (3, 3, 57, 76) (76,)
# (3, 3, 76, 101) (101,)
# (3, 3, 101, 101) (101,)
# (3, 3, 202, 101) (101,)
# (3, 3, 101, 101) (101,)
# (3, 3, 177, 76) (76,)
# (3, 3, 76, 76) (76,)
# (3, 3, 133, 57) (57,)
# (3, 3, 57, 57) (57,)
# (3, 3, 100, 43) (43,)
# (3, 3, 43, 43) (43,)
# (3, 3, 75, 32) (32,)
# (3, 3, 32, 3) (3,)
